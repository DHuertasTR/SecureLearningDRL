# %%
import pandas as pd
import random
import numpy as np

# %%
golden_data=pd.read_csv("./datasets/Colcom2018CleanedScaled.csv",header=0,sep=';')

# %% [markdown]
# ## resumen de los datos originales de malware

# %%
golden_data[data.type=='malicious'].describe()
# Out:
#        tcp_packets  dist_port_tcp  external_ips  vulume_bytes  udp_packets  \
# count  3141.000000    3141.000000   3141.000000   3141.000000  3141.000000
# mean      0.554860       2.253422     -0.045633      0.557717     0.010825
# std       3.220602      18.069049      0.710032      2.810299     0.351354
# min      -0.290698       0.000000     -0.666667     -0.312383     0.000000
# 25%      -0.290698       0.000000     -0.666667     -0.312383     0.000000
# 50%      -0.151163       0.000000     -0.333333     -0.186501     0.000000
# 75%       0.186047       0.000000      0.333333      0.233372     0.000000
# max      54.406977     898.000000      5.666667     64.528792    12.000000
#
#        source_app_packets  remote_app_packets   source_app_bytes  \
# count         3141.000000         3141.000000        3141.000000
# mean             0.536008            0.863371           3.650236
# std              3.106805            5.399236          25.833662
# ...

# %%
generated_data=pd.read_csv("./datasets/malicious_data_generated.csv",header=0,sep=',')

# %%
features=['A','B','C','D','F','G','H','I','j','k']

# %% [markdown]
# ## resumen de los datos generados a partir de fuerza bruta

# %%
generated_data.columns=['tcp_packets','dist_port_tcp','external_ips','vulume_bytes','udp_packets','source_app_packets','remote_app_packets','source_app_bytes','remote_app_bytes','dns_query_times']

# %%
generated_data.describe()
# Out:
#        tcp_packets  dist_port_tcp  external_ips  vulume_bytes  udp_packets  \
# count   498.000000     498.000000    498.000000    498.000000   498.000000
# mean    -26.883534     -29.712851    -39.361446     -9.823293   -29.921687
# std      48.589465      49.687918     42.702022     55.541643    47.479784
# min    -100.000000    -100.000000   -100.000000   -100.000000  -100.000000
# 25%     -64.000000     -67.000000    -72.000000    -58.000000   -66.000000
# 50%     -35.000000     -37.000000    -43.500000    -14.000000   -33.000000
# 75%      -0.250000      -8.000000    -16.250000     32.750000   -10.000000
# max     100.000000     100.000000     95.000000    100.000000    99.000000
#
#        source_app_packets  remote_app_packets  source_app_bytes  \
# count          498.000000          498.000000        498.000000
# mean            18.785141          -23.447791         22.004016
# std             54.777729           48.962786         49.958131
# ...
